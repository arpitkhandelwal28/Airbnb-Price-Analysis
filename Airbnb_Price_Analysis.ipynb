# %% [markdown]
# # **Airbnb Price Analysis**

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('/content/Airbnb_Price_Analysis_Dataset.csv')

# %% [markdown]
# Data Accessing

# %%
# First 5 rows
df.head()
# Out:
#    id              name  host_id host_name neighbourhood_group  \
# 0   1  Airbnb Listing 1     1310     Laura               Bronx
# 1   2  Airbnb Listing 2     1627    Marisa       Staten Island
# 2   3  Airbnb Listing 3     1262    Olivia              Queens
# 3   4  Airbnb Listing 4     1628     Amber            Brooklyn
# 4   5  Airbnb Listing 5     1952    Justin               Bronx
#
#           neighbourhood   latitude  longitude        room_type  price  \
# 0         Bronx Area 14  40.867736 -74.072159  Entire home/apt    451
# 1  Staten Island Area 8  40.893301 -73.863478  Entire home/apt    359
# 2        Queens Area 16  40.596916 -73.793440      Shared room    446
# 3       Brooklyn Area 5  40.859899 -73.731380     Private room    500
# 4          Bronx Area 1  40.694407 -73.991509     Private room    327
#
#    minimum_nights  number_of_reviews  reviews_per_month  availability_365
# 0              12                302               10.3                36
# 1              13                222               11.5               342
# 2               3                216                9.5                88
# 3               2                168                4.5               160
# 4               7                268                2.1               264

# %%
#Last 5 rows
df.tail()
# Out:
#       id                name  host_id host_name neighbourhood_group  \
# 295  296  Airbnb Listing 296     1747   Rebecca            Brooklyn
# 296  297  Airbnb Listing 297     1105    Travis           Manhattan
# 297  298  Airbnb Listing 298     1974    Justin               Bronx
# 298  299  Airbnb Listing 299     1265    Kristi           Manhattan
# 299  300  Airbnb Listing 300     1192    Robert       Staten Island
#
#             neighbourhood   latitude  longitude     room_type  price  \
# 295       Brooklyn Area 8  40.544660 -73.827717  Private room    586
# 296     Manhattan Area 19  40.507914 -74.060211   Shared room    585
# 297          Bronx Area 8  40.719216 -74.003834  Private room    562
# 298     Manhattan Area 17  40.847439 -73.863047   Shared room    580
# 299  Staten Island Area 3  40.775310 -73.787779  Private room     92
#
#      minimum_nights  number_of_reviews  reviews_per_month  availability_365
# 295               5                134                6.0               107
# 296              14                195                5.2               333
# 297              13                167                8.8               255
# 298              15                331                3.9               243
# 299               7                294               11.7               213

# %%
# Shape of dataset
df.shape
# Out:
# (300, 14)

# %%
# Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   300 non-null    int64
#  1   name                 300 non-null    object
#  2   host_id              300 non-null    int64
#  3   host_name            300 non-null    object
#  4   neighbourhood_group  300 non-null    object
#  5   neighbourhood        300 non-null    object
#  6   latitude             300 non-null    float64
#  7   longitude            300 non-null    float64
#  8   room_type            300 non-null    object
#  9   price                300 non-null    int64
#  10  minimum_nights       300 non-null    int64
#  11  number_of_reviews    300 non-null    int64
#  12  reviews_per_month    300 non-null    float64
#  13  availability_365     300 non-null    int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 32.9+ KB

# %%
#Data Types
df.dtypes
# Out:
# id                       int64
# name                    object
# host_id                  int64
# host_name               object
# neighbourhood_group     object
# neighbourhood           object
# latitude               float64
# longitude              float64
# room_type               object
# price                    int64
# minimum_nights           int64
# number_of_reviews        int64
# reviews_per_month      float64
# availability_365         int64
# dtype: object

# %%
# Statistical summary
df.describe()
# Out:
#                id      host_id    latitude   longitude       price  \
# count  300.000000   300.000000  300.000000  300.000000  300.000000
# mean   150.500000  1514.803333   40.700883  -73.896340  333.836667
# std     86.746758   289.203169    0.119994    0.115804  164.223693
# min      1.000000  1003.000000   40.500057  -74.096807   50.000000
# 25%     75.750000  1260.750000   40.597966  -73.990258  191.000000
# 50%    150.500000  1527.500000   40.695967  -73.903550  338.500000
# 75%    225.250000  1764.000000   40.821540  -73.793294  477.500000
# max    300.000000  2000.000000   40.899405  -73.700258  600.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  availability_365
# count      300.000000         300.000000         300.000000        300.000000
# mean         8.210000         180.846667           6.302667        188.286667
# std          4.202949          99.155176           3.561264        105.824638
# min          1.000000           0.000000           0.100000          0.000000
# 25%          5.000000         102.000000           3.300000         99.000000
# 50%          8.000000         185.000000           6.600000        188.500000
# 75%         12.000000         269.250000           9.500000        277.250000
# max         15.000000         350.000000          12.000000        364.000000

# %% [markdown]
# Data Cleaning

# %%
#Check Missing Values
df.isnull().sum()
# Out:
# id                     0
# name                   0
# host_id                0
# host_name              0
# neighbourhood_group    0
# neighbourhood          0
# latitude               0
# longitude              0
# room_type              0
# price                  0
# minimum_nights         0
# number_of_reviews      0
# reviews_per_month      0
# availability_365       0
# dtype: int64

# %%
#Check Duplicate Records
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
#Price Distribution

plt.figure(figsize=(10,6))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Distribution of Airbnb Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#Room Type Distribution

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='room_type')
plt.title('Room Type Distribution')
plt.show()

# %%
#Average Price by Borough

plt.figure(figsize=(10,6))
sns.barplot(data=df,
            x='neighbourhood_group',
            y='price')
plt.title('Average Price by Borough')
plt.show()

# %%
#Availability Analysis

plt.figure(figsize=(10,6))
sns.boxplot(data=df,
            x='room_type',
            y='availability_365')
plt.show()

# %%
#Correlation Heatmap

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
